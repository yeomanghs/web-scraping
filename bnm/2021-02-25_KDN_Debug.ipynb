# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
url = "http://www.moha.gov.my/index.php/ms/kdn1/dir-kdn"

content = requests.get(url)

bsContent = BeautifulSoup(content.text, 'html.parser')

# %%
sectionList = [re.sub("\n|\t", "", i.a.get_text()) for i in bsContent.findAll("h3", {'class' : "page-header item-title"})]

hrefList = [i.a['href'] for i in bsContent.findAll("h3", {'class' : "page-header item-title"})]
# Out:
# ['Pejabat Menteri ',
#  'Pejabat Timbalan Menteri',
#  'Pejabat Timbalan Menteri II',
#  'Pejabat Ketua Setiausaha',
#  'Pejabat Timbalan Ketua Setiausaha (Keselamatan)',
#  'Pejabat Timbalan Ketua Setiausaha (Pengurusan)',
#  'Pejabat Timbalan Ketua Setiausaha (Dasar dan Kawalan)',
#  'Agensi Kawalan Sempadan Malaysia (AKSEM)',
#  'Bahagian Keselamatan',
#  'Bahagian Penguatkuasaan dan Kawalan',
#  'Bahagian Pengurusan Pekerja Asing',
#  'Bahagian Pengurusan Teknologi Maklumat',
#  'Bahagian Pengurusan Sumber Manusia',
#  'Bahagian Antarabangsa',
#  'Bahagian Kepenjaraan, Antidadah dan RELA',
#  'Pejabat Penasihat Undang-Undang',
#  'Bahagian Audit Dalam',
#  'Bahagian Khidmat Pengurusan dan Aset',
#  'Bahagian Hal Ehwal Imigresen',
#  'Pejabat Strategik Nasional (NSO) MAPO',
#  'Unit Komunikasi Korporat',
#  'Bahagian Parlimen dan Kabinet',
#  'Bahagian Perancangan Strategik',
#  'Bahagian Pembangunan',
#  'Bahagian Kewangan',
#  'Pejabat Penapis Filem ',
#  'Bahagian Akaun',
#  'Bahagian Perolehan',
#  'Bahagian Pendaftaran Negara dan Pertubuhan',
#  'Institut Keselamatan Awam Malaysia',
#  'Suruhanjaya Pasukan Polis',
#  'Unit Integriti',
#  'Urus Setia Lembaga Parol',
#  'Urusetia Lembaga Pencegahan Jenayah & Keganasan',
#  'Pejabat Pasukan Petugas Khas NIISe']

# %%
link = hrefList[0]
urlEx = "http://www.moha.gov.my" + link
urlEx
# Out:
# 'http://www.moha.gov.my/index.php/ms/kdn1/dir-kdn/168-pejabat-menteri'

# %%
hrefList[1]
# Out:
# '/index.php/ms/kdn1/dir-kdn/167-pejabat-timbalan-menteri-iii'

# %%
content2 = requests.get(urlEx, verify=False)

bsContent2 = BeautifulSoup(content2.text, 'html.parser')

# %%
allA = [i.a for i in bsContent2.find_all("li") if i.a]

nameList = [re.sub("\n|\t", "", i.get_text()).strip() for i in allA if re.search(re.escape(link + '/'), i['href'])]

phoneList = [re.sub("\n|\t", "", i.get_text()) for i in bsContent2.findAll("div", {"class": "span3 col-md-3"})]

# %%
pandaList = []
for no, link in enumerate(hrefList[:5]):
    time.sleep(3)
    tempDict = {}
    urlEx = "http://www.moha.gov.my" + link
    content2 = requests.get(urlEx, verify=False)
    bsContent2 = BeautifulSoup(content2.text, 'html.parser')
    
    allA = [i.a for i in bsContent2.find_all("li") if i.a]
    nameList = [re.sub("\n|\t", "", i.get_text()).strip() for i in allA if re.search(re.escape(link + '/'), i['href'])]
    phoneList = [re.sub("\n|\t", "", i.get_text()) for i in bsContent2.findAll("div", {"class": "span3 col-md-3"})]
    
    tempDict['Section'] = sectionList[no]
    tempDict['Name'] = nameList
    tempDict['Phone'] = phoneList
    df = pd.DataFrame(tempDict)
    pandaList.append(df)

# %%
dfResult = pd.concat(pandaList).reset_index()
del dfResult['index']
dfResult
# Out:
#                                             Section  \
# 0                                  Pejabat Menteri
# 1                                  Pejabat Menteri
# 2                                  Pejabat Menteri
# 3                                  Pejabat Menteri
# 4                                  Pejabat Menteri
# 5                                  Pejabat Menteri
# 6                                  Pejabat Menteri
# 7                                  Pejabat Menteri
# 8                                  Pejabat Menteri
# 9                                  Pejabat Menteri
# 10                         Pejabat Timbalan Menteri
# 11                         Pejabat Timbalan Menteri
# 12                         Pejabat Timbalan Menteri
# 13                         Pejabat Timbalan Menteri
# 14                         Pejabat Timbalan Menteri
# 15                         Pejabat Timbalan Menteri
# 16                      Pejabat Timbalan Menteri II
# 17                      Pejabat Timbalan Menteri II
# 18                      Pejabat Timbalan Menteri II
# 19                      Pejabat Timbalan Menteri II
# 20                      Pejabat Timbalan Menteri II
# 21                      Pejabat Timbalan Menteri II
# 22                      Pejabat Timbalan Menteri II
# 23                         Pejabat Ketua Setiausaha
# 24                         Pejabat Ketua Setiausaha
# 25                         Pejabat Ketua Setiausaha
# 26                         Pejabat Ketua Setiausaha
# 27                         Pejabat Ketua Setiausaha
# 28                         Pejabat Ketua Setiausaha
# 29                         Pejabat Ketua Setiausaha
# 30                         Pejabat Ketua Setiausaha
# 31                         Pejabat Ketua Setiausaha
# 32  Pejabat Timbalan Ketua Setiausaha (Keselamatan)
# 33  Pejabat Timbalan Ketua Setiausaha (Keselamatan)
# 34  Pejabat Timbalan Ketua Setiausaha (Keselamatan)
#
#                                                  Name                  Phone
# 0                   YB Dato' Seri Hamzah bin Zainudin
# 1               Nik Faranas Suraya binti Nik Shahiran  Telefon: 03-8886 8007
# 2          Sayed Amir Muzzakkir bin Al Sayed Mohammad  Telefon: 03-8886 8019
# 3                             Jumiyati binti Mohd Noh  Telefon: 03-8886 8474
# 4                             Dato’ Arifin bin Tobias  Telefon: 03-8886 8088
# 5                           Atiqah Solehah binti Arip  Telefon: 03-8886 8386
# 6                                 Zulkifli bin Bujang  Telefon: 03-8886 8305
# 7                 Nur Syaza Hanifah binti Mohd Samudi  Telefon: 03-8886 8082
# 8                          Aimi Syahirah binti Rosman  Telefon: 03-8886 8091
# 9                             Ahmad Ikhwan bin Fadhli  Telefon: 03-8886 3950
# 10  YB Dato' Sri Dr Haji Ismail bin Haji Mohamed Said
# 11                         Cynthia Anak Boniface Bana  Telefon: 03-8886 8625
# 12                         Normazalina binti Mohd Nor  Telefon: 03-8886 8624
# 13                        Mohd Aizat bin Sharin Yusop  Telefon: 03-8886 8297
# 14                 Raja Muhamad Hafizd bin Raja Ahmad  Telefon: 03-8886 8512
# 15                          Amat Fauzi bin Amat Rohim  Telefon: 03-8886 8307
# 16                         YB Tuan Jonathan bin Yasin
# 17                             Mardiana binti Baharum  Telefon: 03-8886 8331
# 18                                   Hussen bin Jirat  Telefon: 03-8886 8130
# 19                                Lajim bin Abd Momen  Telefon: 03-8886 8232
# 20                     Zulfadzli Hisham Bin Abu Zahni  Telefon: 03-8886 3451
# 21                        Ahmad Shah Ziri bin Mohamed  Telefon: 03-8886 8271
# 22                         Nurul Syafiqah binti Kiram  Telefon: 03-8886 8271
# 23   YBhg. Datuk Wan Ahmad Dahlan bin Haji Abdul Aziz  Telefon: 03-8000 8080
# 24                         Marziana binti Abdul Malik  Telefon: 03-8886 8076
# 25                            Syariman bin Mat Salleh  Telefon: 03-8000 8000
# 26                               DSP Zaini bin Othman  Telefon: 03-8886 8507
# 27                          Siti Hanizah binti Tupani  Telefon: 03-8886 8089
# 28                    Muhammad Arshad bin Barkatullah  Telefon: 03-8886 8504
# 29                           Muhamad Hanif bin Hanuar  Telefon: 03-8886 8046
# 30                                Nabilah binti Yusof  Telefon: 03-8886 8046
# 31                         Ahmad Faris bin Ahmad@Musa  Telefon: 03-8886 8505
# 32     YBhg. Dato' Hj Abdul Halim bin Hj Abdul Rahman  Telefon: 03-8886 8079
# 33                             Irza Laily binti Rajab  Telefon: 03-8886 8080
# 34                             Ahmad Badrul bin Adnan  Telefon: 03-8886 8282
